# %%
import pandas as pd

ob = pd.read_parquet('data_BTCUSDC/orderbook_snapshots/BTCUSDC_orderbook_snapshots_20251224_16.parquet')
ob['exchange_ts'] = pd.to_datetime(ob['exchange_ts'], unit='ms')
ob
# Out:
#                 exchange_ts  local_recv_ts   lastUpdateId   bid_price_0  \
# 0   2025-12-24 15:59:59.192  1766591999518  9531365146459  86973.601562
# 1   2025-12-24 15:59:59.935  1766592000032  9531365188721  86973.601562
# 2   2025-12-24 16:00:00.468  1766592000540  9531365233858  86973.601562
# 3   2025-12-24 16:00:00.468  1766592001051  9531365233858  86973.601562
# 4   2025-12-24 16:00:00.468  1766592002247  9531365233858  86973.601562
# ..                      ...            ...            ...           ...
# 919 2025-12-24 16:08:38.296  1766592518397  9531424849956  87016.796875
# 920 2025-12-24 16:08:38.811  1766592518910  9531424894232  87016.796875
# 921 2025-12-24 16:08:39.334  1766592519429  9531424925083  87016.796875
# 922 2025-12-24 16:08:39.852  1766592519946  9531424952909  87016.796875
# 923 2025-12-24 16:08:40.379  1766592520477  9531424983498  87016.796875
#
#      bid_qty_0   ask_price_0  ask_qty_0   bid_price_1  bid_qty_1  \
# ...

# %%
# ob['bid_price_0'] - ob['bid_price_999']
ob['ask_price_999'] - ob['ask_price_0']
# Out:
# 0      349.796875
# 1      354.195312
# 2      356.093750
# 3      356.093750
# 4      356.093750
#           ...
# 919    321.703125
# 920    320.304688
# 921    320.101562
# 922    319.804688
# 923    319.398438
# Length: 924, dtype: float32

# %%
24 * 10
# Out:
# 240
